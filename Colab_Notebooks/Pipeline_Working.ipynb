# %%
import pickle
import numpy as np
import warnings

warnings.filterwarnings('ignore')

model = pickle.load(open('model.pkl','rb'))

# %%
data = ['Toyota', 'Third Party', 'Diesel', 5, 5000, 'Third or More Owners', 1496, 'Automatic', 17.6, 88.7, 14, 'Oct', 2019, 'Pune']
data = np.array(data).reshape(1,-1)

# %%
model.predict(data)[0]
# Out:
# 11.125318
